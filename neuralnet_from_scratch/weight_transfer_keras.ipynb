# %% [markdown]
# Out of curiosity I will train a model with identical architecture using keras and export the weights and biases, then load it into my model and see how it performs.

# %%
import pandas as pd
import numpy as np
from tensorflow import keras
import tensorflow as tf
from sklearn.model_selection import train_test_split

# %%
train = pd.read_csv("/Users/homelab/Desktop/deep_learning/mnist_cleaner/archive/mnist_train.csv")
test = pd.read_csv("/Users/homelab/Desktop/deep_learning/mnist_cleaner/archive/mnist_test.csv")

# %%
x_train_full = train.drop(columns=["label"]) /255
y_train_full = train["label"]

x_test = test.drop(columns=["label"]) /255
y_test = test["label"]

x_train, x_valid, y_train, y_valid = train_test_split(x_train_full, y_train_full, test_size=0.2, stratify=y_train_full, random_state=11)

# %%
model = keras.Sequential([
    keras.layers.Input([784]),
    keras.layers.Dense(128, activation="relu", kernel_initializer="he_normal"),
    keras.layers.Dense(128, activation="relu", kernel_initializer="he_normal"),
    keras.layers.Dense(10, activation="softmax", kernel_initializer="he_normal")
])

sgd_optimizer = keras.optimizers.SGD(learning_rate=0.01)

model.compile(
    loss="sparse_categorical_crossentropy",
    optimizer=sgd_optimizer,
    metrics=["accuracy"])

earlystopping_cb = keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)

history = model.fit(x_train, y_train,
                      validation_data=(x_valid, y_valid),
                      epochs=150,
                      callbacks=[earlystopping_cb],
                      batch_size=128)
# Out:
# Epoch 1/150
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5334 - loss: 1.6595 - val_accuracy: 0.8486 - val_loss: 0.6058
# Epoch 2/150
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8628 - loss: 0.5368 - val_accuracy: 0.8865 - val_loss: 0.4159
# Epoch 3/150
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8893 - loss: 0.4093 - val_accuracy: 0.8986 - val_loss: 0.3564
# Epoch 4/150
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9018 - loss: 0.3543 - val_accuracy: 0.9073 - val_loss: 0.3210
# Epoch 5/150
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9112 - loss: 0.3147 - val_accuracy: 0.9143 - val_loss: 0.2993
# Epoch 6/150
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9168 - loss: 0.2964 - val_accuracy: 0.9181 - val_loss: 0.2835
# Epoch 7/150
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9222 - loss: 0.2751 - val_accuracy: 0.9216 - val_loss: 0.2693
# Epoch 8/150
# ...

# %%
# 1. Get list of all parameters [W1, b1, W2, b2, W3, b3]
weights = model.get_weights()

# 2. Save as a compressed NumPy dictionary archive
np.savez(
    "keras_extracted_weights.npz",
    W1=weights[0],
    b1=weights[1],
    W2=weights[2],
    b2=weights[3],
    W3=weights[4],
    b3=weights[5],
)
